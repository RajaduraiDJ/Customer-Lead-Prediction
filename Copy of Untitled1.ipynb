# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-10686b38-559b-40c0-8570-3dc8e63a81d3" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-10686b38-559b-40c0-8570-3dc8e63a81d3">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import io

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9240 entries, 0 to 9239
# Data columns (total 37 columns):
#  #   Column                                         Non-Null Count  Dtype
# ---  ------                                         --------------  -----
#  0   Prospect ID                                    9240 non-null   object
#  1   Lead Number                                    9240 non-null   int64
#  2   Lead Origin                                    9240 non-null   object
#  3   Lead Source                                    9204 non-null   object
#  4   Do Not Email                                   9240 non-null   object
#  5   Do Not Call                                    9240 non-null   object
#  6   Converted                                      9240 non-null   int64
#  7   TotalVisits                                    9103 non-null   float64
#  8   Total Time Spent on Website                    9240 non-null   int64
# ...

# %%
dataset.describe()
# Out:
#          Lead Number    Converted  TotalVisits  Total Time Spent on Website  \
# count    9240.000000  9240.000000  9103.000000                  9240.000000
# mean   617188.435606     0.385390     3.445238                   487.698268
# std     23405.995698     0.486714     4.854853                   548.021466
# min    579533.000000     0.000000     0.000000                     0.000000
# 25%    596484.500000     0.000000     1.000000                    12.000000
# 50%    615479.000000     0.000000     3.000000                   248.000000
# 75%    637387.250000     1.000000     5.000000                   936.000000
# max    660737.000000     1.000000   251.000000                  2272.000000
#
#        Page Views Per Visit  Asymmetrique Activity Score  \
# count           9103.000000                  5022.000000
# mean               2.362820                    14.306252
# std                2.161418                     1.386694
# ...

# %%
dataset.columns
# Out:
# Index(['Prospect ID', 'Lead Number', 'Lead Origin', 'Lead Source',
#        'Do Not Email', 'Do Not Call', 'Converted', 'TotalVisits',
#        'Total Time Spent on Website', 'Page Views Per Visit', 'Last Activity',
#        'Country', 'Specialization', 'How did you hear about X Education',
#        'What is your current occupation',
#        'What matters most to you in choosing a course', 'Search', 'Magazine',
#        'Newspaper Article', 'X Education Forums', 'Newspaper',
#        'Digital Advertisement', 'Through Recommendations',
#        'Receive More Updates About Our Courses', 'Tags', 'Lead Quality',
#        'Update me on Supply Chain Content', 'Get updates on DM Content',
#        'Lead Profile', 'City', 'Asymmetrique Activity Index',
#        'Asymmetrique Profile Index', 'Asymmetrique Activity Score',
#        'Asymmetrique Profile Score',
#        'I agree to pay the amount through cheque',
#        'A free copy of Mastering The Interview', 'Last Notable Activity'],
# ...

# %%
sns.pairplot(dataset)

# %%
print(dataset.dtypes)
# Out:
# Prospect ID                                       object
# Lead Number                                        int64
# Lead Origin                                       object
# Lead Source                                       object
# Do Not Email                                      object
# Do Not Call                                       object
# Converted                                          int64
# TotalVisits                                      float64
# Total Time Spent on Website                        int64
# Page Views Per Visit                             float64
# Last Activity                                     object
# Country                                           object
# Specialization                                    object
# How did you hear about X Education                object
# What is your current occupation                   object
# What matters most to you in choosing a course     object
# ...

# %%
numeric_dataset = dataset.select_dtypes(include=[np.number])

# %%
print(numeric_dataset.isnull().sum())
# Out:
# Lead Number                       0
# Converted                         0
# TotalVisits                     137
# Total Time Spent on Website       0
# Page Views Per Visit            137
# Asymmetrique Activity Score    4218
# Asymmetrique Profile Score     4218
# dtype: int64

# %%
numeric_dataset = numeric_dataset.dropna()

# %%
correlation_matrix = numeric_dataset.corr()
sns.heatmap(correlation_matrix, annot=True, fmt=".2f")
plt.show()

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score

# %%
np.random.seed(0)
X = 2 * np.random.rand(100, 1)
y = 4 + 3 * X + np.random.randn(100, 1)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

# %%
model = LinearRegression()

# %%
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(X_test)

# %%
mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

# %%
print("Coefficients:", model.coef_)
print("Intercept:", model.intercept_)
print("Mean squared error:", mse)
print("R-squared:", r2)
# Out:
# Coefficients: [[2.93647151]]
# Intercept: [4.32235853]
# Mean squared error: 1.0434333815695171
# R-squared: 0.7424452332071367

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(X_test, y_test, color='black', label='Actual data')
plt.plot(X_test, y_pred, color='blue', linewidth=3, label='Predicted data')
plt.xlabel('Total Visits')
plt.ylabel('Total Time Spent on Website')
plt.title('Linear Regression')
plt.legend()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('/content/Leads.csv')

# %%
print(df)
# Out:
#                                Prospect ID  Lead Number  \
# 0     7927b2df-8bba-4d29-b9a2-b6e0beafe620       660737
# 1     2a272436-5132-4136-86fa-dcc88c88f482       660728
# 2     8cc8c611-a219-4f35-ad23-fdfd2656bd8a       660727
# 3     0cc2df48-7cf4-4e39-9de9-19797f9b38cc       660719
# 4     3256f628-e534-4826-9d63-4a8b88782852       660681
# ...                                    ...          ...
# 9235  19d6451e-fcd6-407c-b83b-48e1af805ea9       579564
# 9236  82a7005b-7196-4d56-95ce-a79f937a158d       579546
# 9237  aac550fe-a586-452d-8d3c-f1b62c94e02c       579545
# 9238  5330a7d1-2f2b-4df4-85d6-64ca2f6b95b9       579538
# 9239  571b5c8e-a5b2-4d57-8574-f2ffb06fdeff       579533
#
#                   Lead Origin     Lead Source Do Not Email Do Not Call  \
# 0                         API      Olark Chat           No          No
# 1                         API  Organic Search           No          No
# 2     Landing Page Submission  Direct Traffic           No          No
# ...

# %%
df = pd.read_csv('/content/Leads.csv')

# %%
x = df['TotalVisits']
y = df['Total Time Spent on Website']

# %%
plt.figure(figsize=(10, 6))
plt.scatter(x, y, alpha=0.5)
plt.title('Total Visits vs. Total Time Spent on Website')
plt.xlabel('Total Visits')
plt.ylabel('Total Time Spent on Website')
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(30, 10))
plt.scatter(x, y, alpha=0.5)
plt.title('Lead Converted')
plt.xlabel('Converted')
plt.ylabel('Lead Number')
plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt

# %%
import matplotlib.pyplot as plt

# %%
categories = ['search', 'Magazine', 'Newspaper Article', 'X Education Forums', 'Newspaper', 'Digital Advertisement', 'Through Recommendations']
values = [10, 20, 15, 25, 30, 40, 35]

# %%
plt.figure(figsize=(10, 6))
plt.bar(categories, values, color='skyblue')
plt.title('Bar Chart')
plt.xlabel('Categories')
plt.ylabel('Values')
plt.xticks(rotation=45)
plt.grid(True)
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = {
    'City': ['Mumbai', 'Other Cities', 'Other Metro Cities', 'Thane and Outskirts'],
    'Converted': [20, 30, 25, 35]
}

# %%
from sklearn.linear_model import LogisticRegression

# %%
import pandas as pd

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
import os

# %%
import pandas as pd

# %%
df = pd.read_csv('/content/Leads.csv')

# %%
print(df.head())
# Out:
#                             Prospect ID  Lead Number              Lead Origin  \
# 0  7927b2df-8bba-4d29-b9a2-b6e0beafe620       660737                      API
# 1  2a272436-5132-4136-86fa-dcc88c88f482       660728                      API
# 2  8cc8c611-a219-4f35-ad23-fdfd2656bd8a       660727  Landing Page Submission
# 3  0cc2df48-7cf4-4e39-9de9-19797f9b38cc       660719  Landing Page Submission
# 4  3256f628-e534-4826-9d63-4a8b88782852       660681  Landing Page Submission
#
#       Lead Source Do Not Email Do Not Call  Converted  TotalVisits  \
# 0      Olark Chat           No          No          0          0.0
# 1  Organic Search           No          No          0          5.0
# 2  Direct Traffic           No          No          1          2.0
# 3  Direct Traffic           No          No          0          1.0
# 4          Google           No          No          1          2.0
#
#    Total Time Spent on Website  Page Views Per Visit  ...  \
# ...

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8230 entries, 0 to 8229
# Data columns (total 37 columns):
#  #   Column                                         Non-Null Count  Dtype
# ---  ------                                         --------------  -----
#  0   Prospect ID                                    8230 non-null   object
#  1   Lead Number                                    8230 non-null   int64
#  2   Lead Origin                                    8230 non-null   object
#  3   Lead Source                                    8197 non-null   object
#  4   Do Not Email                                   8230 non-null   object
#  5   Do Not Call                                    8230 non-null   object
#  6   Converted                                      8230 non-null   int64
#  7   TotalVisits                                    8096 non-null   float64
#  8   Total Time Spent on Website                    8230 non-null   int64
# ...

# %%
print(df.index)
# Out:
# RangeIndex(start=0, stop=8230, step=1)

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score

# %%
target = df['TotalVisits']

# %%
features = df[['TotalVisits', 'Total Time Spent on Website', 'Page Views Per Visit']]

# %%
features.fillna(features.mean(), inplace=True)
# Out:
# <ipython-input-73-2ee3d703fa78>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   features.fillna(features.mean(), inplace=True)

# %%
target.fillna(target.mean(), inplace=True)

# %%
X_train, X_test, y_train, y_test = train_test_split(features, target, test_size=0.2, random_state=42)

# %%
model = LinearRegression()

# %%
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(X_test)

# %%
mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

# %%
print("Mean Squared Error:", mse)
print("R-squared Score:", r2)
# Out:
# Mean Squared Error: 8.935670937192867e-30
# R-squared Score: 1.0

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

# %%
import pandas as pd

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from matplotlib.pyplot import xticks
# %matplotlib inline

# %%
pd.set_option('display.max_rows', 100)
pd.set_option('display.max_columns', 100)

# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).

# %%
df = pd.read_csv('/content/drive/MyDrive/Customer lead prediction/Leads csv file/Leads.csv')

# %%
df.head(5)
# Out:
#                             Prospect ID  Lead Number              Lead Origin  \
# 0  7927b2df-8bba-4d29-b9a2-b6e0beafe620       660737                      API
# 1  2a272436-5132-4136-86fa-dcc88c88f482       660728                      API
# 2  8cc8c611-a219-4f35-ad23-fdfd2656bd8a       660727  Landing Page Submission
# 3  0cc2df48-7cf4-4e39-9de9-19797f9b38cc       660719  Landing Page Submission
# 4  3256f628-e534-4826-9d63-4a8b88782852       660681  Landing Page Submission
#
#       Lead Source Do Not Email Do Not Call  Converted  TotalVisits  \
# 0      Olark Chat           No          No          0          0.0
# 1  Organic Search           No          No          0          5.0
# 2  Direct Traffic           No          No          1          2.0
# 3  Direct Traffic           No          No          0          1.0
# 4          Google           No          No          1          2.0
#
#    Total Time Spent on Website  Page Views Per Visit            Last Activity  \
# ...

# %%
df.shape
# Out:
# (9240, 37)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9240 entries, 0 to 9239
# Data columns (total 37 columns):
#  #   Column                                         Non-Null Count  Dtype
# ---  ------                                         --------------  -----
#  0   Prospect ID                                    9240 non-null   object
#  1   Lead Number                                    9240 non-null   int64
#  2   Lead Origin                                    9240 non-null   object
#  3   Lead Source                                    9204 non-null   object
#  4   Do Not Email                                   9240 non-null   object
#  5   Do Not Call                                    9240 non-null   object
#  6   Converted                                      9240 non-null   int64
#  7   TotalVisits                                    9103 non-null   float64
#  8   Total Time Spent on Website                    9240 non-null   int64
# ...

# %%
df.describe()
# Out:
#          Lead Number    Converted  TotalVisits  Total Time Spent on Website  \
# count    9240.000000  9240.000000  9103.000000                  9240.000000
# mean   617188.435606     0.385390     3.445238                   487.698268
# std     23405.995698     0.486714     4.854853                   548.021466
# min    579533.000000     0.000000     0.000000                     0.000000
# 25%    596484.500000     0.000000     1.000000                    12.000000
# 50%    615479.000000     0.000000     3.000000                   248.000000
# 75%    637387.250000     1.000000     5.000000                   936.000000
# max    660737.000000     1.000000   251.000000                  2272.000000
#
#        Page Views Per Visit  Asymmetrique Activity Score  \
# count           9103.000000                  5022.000000
# mean               2.362820                    14.306252
# std                2.161418                     1.386694
# ...

# %%
df = df.replace('Select', np.nan)

# %%
df.isnull().sum()
# Out:
# Prospect ID                                         0
# Lead Number                                         0
# Lead Origin                                         0
# Lead Source                                        36
# Do Not Email                                        0
# Do Not Call                                         0
# Converted                                           0
# TotalVisits                                       137
# Total Time Spent on Website                         0
# Page Views Per Visit                              137
# Last Activity                                     103
# Country                                          2461
# Specialization                                   3380
# How did you hear about X Education               7250
# What is your current occupation                  2690
# What matters most to you in choosing a course    2709
# Search                                              0
# ...

# %%
df['Lead Quality'].describe()
# Out:
# count         4473
# unique           5
# top       Might be
# freq          1560
# Name: Lead Quality, dtype: object

# %%
sns.countplot(df['Lead Quality'])
# Out:
# <Axes: xlabel='count', ylabel='Lead Quality'>

# %%
df['Lead Quality'] = df['Lead Quality'].replace(np.nan, 'Not Sure')

# %%
sns.countplot(df['Lead Quality'])
# Out:
# <Axes: xlabel='count', ylabel='Lead Quality'>

# %%
df.City.describe()
# Out:
# count       5571
# unique         6
# top       Mumbai
# freq        3222
# Name: City, dtype: object

# %%
sns.countplot(df.City)
xticks(rotation = 90)
# Out:
# (array([   0.,  500., 1000., 1500., 2000., 2500., 3000., 3500.]),
#  [Text(0.0, 0, '0'),
#   Text(500.0, 0, '500'),
#   Text(1000.0, 0, '1000'),
#   Text(1500.0, 0, '1500'),
#   Text(2000.0, 0, '2000'),
#   Text(2500.0, 0, '2500'),
#   Text(3000.0, 0, '3000'),
#   Text(3500.0, 0, '3500')])

# %%
df.Specialization.describe()
# Out:
# count                   5860
# unique                    18
# top       Finance Management
# freq                     976
# Name: Specialization, dtype: object

# %%
sns.countplot(df.Specialization)
xticks(rotation = 90)
# Out:
# (array([   0.,  200.,  400.,  600.,  800., 1000., 1200.]),
#  [Text(0.0, 0, '0'),
#   Text(200.0, 0, '200'),
#   Text(400.0, 0, '400'),
#   Text(600.0, 0, '600'),
#   Text(800.0, 0, '800'),
#   Text(1000.0, 0, '1000'),
#   Text(1200.0, 0, '1200')])

# %%
df.Tags.describe()
# Out:
# count                                    5887
# unique                                     26
# top       Will revert after reading the email
# freq                                     2072
# Name: Tags, dtype: object

# %%
fig, axs = plt.subplots(figsize = (15,7.5))
sns.countplot(df.Tags)
xticks(rotation = 90)
# Out:
# (array([   0.,  250.,  500.,  750., 1000., 1250., 1500., 1750., 2000.,
#         2250.]),
#  [Text(0.0, 0, '0'),
#   Text(250.0, 0, '250'),
#   Text(500.0, 0, '500'),
#   Text(750.0, 0, '750'),
#   Text(1000.0, 0, '1000'),
#   Text(1250.0, 0, '1250'),
#   Text(1500.0, 0, '1500'),
#   Text(1750.0, 0, '1750'),
#   Text(2000.0, 0, '2000'),
#   Text(2250.0, 0, '2250')])

# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).

# %%
import pandas as pd

# %%
df = pd.read_csv('/content/drive/MyDrive/Customer lead prediction/Leads csv file/Leads.csv')

# %%
df.shape
# Out:
# (9240, 37)

# %%
import numpy as np

# %%
df['Lead Quality'] = df['Lead Quality'].replace(np.nan, 'Not Sure')

# %%
print(df.shape)
# Out:
# (9240, 37)

# %%
df["Last Notable Activity"].value_counts()
# Out:
# Last Notable Activity
# Modified                        3407
# Email Opened                    2827
# SMS Sent                        2172
# Page Visited on Website          318
# Olark Chat Conversation          183
# Email Link Clicked               173
# Email Bounced                     60
# Unsubscribed                      47
# Unreachable                       32
# Had a Phone Conversation          14
# Email Marked Spam                  2
# Approached upfront                 1
# Resubscribed to emails             1
# View in browser link Clicked       1
# Form Submitted on Website          1
# Email Received                     1
# Name: count, dtype: int64

# %%
Converted
# Out:
# 38.53896103896104

# %%
selected_columns = df.iloc[:, [6, 7, 9]]

# %%
print(selected_columns)
# Out:
#       Converted  TotalVisits  Page Views Per Visit
# 0             0          0.0                  0.00
# 1             0          5.0                  2.50
# 2             1          2.0                  2.00
# 3             0          1.0                  1.00
# 4             1          2.0                  1.00
# ...         ...          ...                   ...
# 8225          1          4.0                  2.00
# 8226          1          3.0                  3.00
# 8227          0          2.0                  2.00
# 8228          1          6.0                  6.00
# 8229          1          9.0                  2.25
#
# [8230 rows x 3 columns]

# %%
df['Converted'].value_counts()
# Out:
# Converted
# 0    5019
# 1    3211
# Name: count, dtype: int64

# %%
missing_percentage = df.isnull().mean() * 100

# %%
df.isnull().mean() * 100
# Out:
# Prospect ID                                       0.000000
# Lead Number                                       0.000000
# Lead Origin                                       0.000000
# Lead Source                                       0.400972
# Do Not Email                                      0.000000
# Do Not Call                                       0.000000
# Converted                                         0.000000
# TotalVisits                                       1.628190
# Total Time Spent on Website                       0.000000
# Page Views Per Visit                              1.628190
# Last Activity                                     1.215067
# Country                                          26.986634
# Specialization                                   15.516403
# How did you hear about X Education               23.791009
# What is your current occupation                  29.295261
# What matters most to you in choosing a course    29.513973
# ...

# %%
numeric_df = df.select_dtypes(include=['number'])
correlation_matrix = numeric_df.corr()

# %%
import pandas as pd

# %%
string_value = "3.14159"

# %%
float_value = float(string_value)

# %%
print(float_value)
# Out:
# 3.14159

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data = {
    'Converted': 0.000000,
    'TotalVisits': 1.628190,
    'Total Time Spent on Website': 0.000000,
    'Page Views Per Visit': 1.628190,
    'Last Activity': 1.215067,
    'Country': 26.986634}

# %%
df = pd.DataFrame(data.items(), columns=['Variable', 'Percentage'])

# %%
plt.figure(figsize=(10, 6))
sns.barplot(x='Percentage', y='Variable', data=df, palette='viridis')
plt.title('Percentage of Data for Each Variable')
plt.xlabel('Percentage')
plt.ylabel('Variable')
plt.show()
# Out:
# <ipython-input-167-8f43c27d557f>:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Percentage', y='Variable', data=df, palette='viridis')

# %%
df.columns
# Out:
# Index(['Variable', 'Percentage'], dtype='object')

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
x = np.array(["Lead Number", "Converted"])
y = np.array([3, 15, 40, 50])

# %%
x = ['Converted', 'TotalVisits', 'Total Time Spent on Website', 'Page Views Per Visit', 'Last Activity', 'Country']
y = [0.000000, 1.628190, 0.000000, 1.628190, 1.215067, 26.986634]

# %%
plt.figure(figsize=(10, 6))
plt.bar(x, y, color='skyblue')
plt.title('Percentage of Data for Each Variable')
plt.xlabel('Variable')
plt.ylabel('Percentage')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %%
data = df

# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).

# %%
df = pd.read_csv('/content/drive/MyDrive/Customer lead prediction/Leads csv file/Leads.csv')

# %%
df['Lead Origin'].value_counts()
# Out:
# Lead Origin
# Landing Page Submission    4886
# API                        3580
# Lead Add Form               718
# Lead Import                  55
# Quick Add Form                1
# Name: count, dtype: int64

# %%
fig, axs = plt.subplots(figsize=(15, 7.5))
sns.countplot(x="Lead Origin", hue="Converted", data=data, order=data['Lead Origin'].value_counts().index)
plt.xticks(rotation=45)
plt.show()

# %%
df['Lead Source'].value_counts()
# Out:
# Lead Source
# Google               2868
# Direct Traffic       2543
# Olark Chat           1755
# Organic Search       1154
# Reference             534
# Welingak Website      142
# Referral Sites        125
# Facebook               55
# bing                    6
# google                  5
# Click2call              4
# Press_Release           2
# Social Media            2
# Live Chat               2
# youtubechannel          1
# testone                 1
# Pay per Click Ads       1
# welearnblog_Home        1
# WeLearn                 1
# blog                    1
# NC_EDM                  1
# Name: count, dtype: int64

# %%
df['Lead Source'] = df['Lead Source'].replace(['google'], 'Google')
df['Lead Source'] = df['Lead Source'].replace(['Click2call',
'Live Chat',
                                                   'NC_EDM',
                                                   'Pay per Click Ads',
                                                   'Press_Release',
                                                   'Social Media',
                                                   'WeLearn',
                                                   'bing',
                                                   'blog',
                                                   'testone',
                                                   'welearnblog_Home',
                                                   'youtubechannel'], 'Others')

# %%
sns.countplot(x = "Lead Source", hue = "Converted", data = data, order = data['Lead Source'].value_counts().index)
plt.xticks(rotation = 45)
plt.show()
